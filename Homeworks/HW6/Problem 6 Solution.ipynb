# %%
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split

# load the data for digits 0, 1, and 2
X_0 = np.loadtxt('/content/digit0.txt', delimiter=',')
X_1 = np.loadtxt('/content/digit1.txt', delimiter=',')
X_2 = np.loadtxt('/content/digit2.txt', delimiter=',')

# create the labels for the data
y_0 = np.zeros(X_0.shape[0])
y_1 = np.ones(X_1.shape[0])
y_2 = 2 * np.ones(X_2.shape[0])

# concatenate the data and labels
X = np.concatenate((X_0, X_1, X_2), axis=0)
y = np.concatenate((y_0, y_1, y_2), axis=0)

# convert the labels to one-hot encoding
y = tf.keras.utils.to_categorical(y, num_classes=3)

# split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# define the neural network model
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(12, activation='sigmoid', input_dim=X.shape[1]),
    tf.keras.layers.Dense(3, activation='softmax')
])

# compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# train the model
model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# evaluate the model on the testing data
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Test loss: {loss:.3f}')
print(f'Test accuracy: {accuracy:.3f}')
# Out:
# Epoch 1/100
# 65/65 [==============================] - 2s 10ms/step - loss: 0.5866 - accuracy: 0.8069 - val_loss: 0.3560 - val_accuracy: 0.9613
# Epoch 2/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.2931 - accuracy: 0.9737 - val_loss: 0.2340 - val_accuracy: 0.9829
# Epoch 3/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.2023 - accuracy: 0.9829 - val_loss: 0.1711 - val_accuracy: 0.9875
# Epoch 4/100
# 65/65 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9873 - val_loss: 0.1344 - val_accuracy: 0.9863
# Epoch 5/100
# 65/65 [==============================] - 0s 5ms/step - loss: 0.1205 - accuracy: 0.9917 - val_loss: 0.1087 - val_accuracy: 0.9875
# Epoch 6/100
# 65/65 [==============================] - 0s 6ms/step - loss: 0.0985 - accuracy: 0.9927 - val_loss: 0.0908 - val_accuracy: 0.9875
# Epoch 7/100
# ...
